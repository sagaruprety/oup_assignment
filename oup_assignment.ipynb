# %%
from pydantic import BaseModel
from collections import defaultdict
import json

# loading the parsed sentence json file
f = open('./data/sample_parsed_sentences.json')
 
input_data = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from pydantic import BaseModel
#       2 from collections import defaultdict
#       3 import json
#
# ModuleNotFoundError: No module named 'pydantic'

# %%
input_data
# Out:
# {'sentences': [{'sentence_text': '2019 жылы 27 желтоқсанда Президент "Қазақстан Республикасының кейбір заңнамалық актілеріне қылмыстық, қылмыстық іс жүргізу заңнамасын жетілдіру және жеке адамның құқықтарын қорғауды күшейту мәселелері бойынша өзгерістер мен толықтырулар енгізу туралы" Заңға қол қойды.',
#    'tokens': [{'id': '1',
#      'text': '2019',
#      'lemma': '2019',
#      'pos': 'NUM',
#      'pos_finegrained': 'num',
#      'feats': 'NumType=Ord',
#      'start_char': '0',
#      'end_char': '4'},
#     {'id': '2',
#      'text': 'жылы',
#      'lemma': 'жыл',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '5',
#      'end_char': '9'},
#     {'id': '3',
#      'text': '27',
#      'lemma': '27',
#      'pos': 'NUM',
#      'pos_finegrained': 'num',
#      'feats': 'NumType=Ord',
#      'start_char': '10',
#      'end_char': '12'},
#     {'id': '4',
#      'text': 'желтоқсанда',
#      'lemma': 'желтоқсан',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Loc',
#      'start_char': '13',
#      'end_char': '24'},
#     {'id': '5',
#      'text': 'Президент',
#      'lemma': 'президент',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '25',
#      'end_char': '34'},
#     {'id': '6',
#      'text': '"',
#      'lemma': '"',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'sent',
#      'feats': None,
#      'start_char': '35',
#      'end_char': '36'},
#     {'id': '7',
#      'text': 'Қазақстан',
#      'lemma': 'Қазақстан',
#      'pos': 'PROPN',
#      'pos_finegrained': 'np',
#      'feats': 'Case=Nom',
#      'start_char': '36',
#      'end_char': '45'},
#     {'id': '8',
#      'text': 'Республикасының',
#      'lemma': 'республика',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Gen|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '46',
#      'end_char': '61'},
#     {'id': '9',
#      'text': 'кейбір',
#      'lemma': 'кейбір',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '62',
#      'end_char': '68'},
#     {'id': '10',
#      'text': 'заңнамалық',
#      'lemma': 'заңнамалық',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '69',
#      'end_char': '79'},
#     {'id': '11',
#      'text': 'актілеріне',
#      'lemma': 'акт',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Ins|Number=Plur|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '80',
#      'end_char': '90'},
#     {'id': '12',
#      'text': 'қылмыстық',
#      'lemma': 'қылмыстық',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '91',
#      'end_char': '100'},
#     {'id': '13',
#      'text': ',',
#      'lemma': ',',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'cm',
#      'feats': None,
#      'start_char': '100',
#      'end_char': '101'},
#     {'id': '14',
#      'text': 'қылмыстық',
#      'lemma': 'қылмыстық',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '102',
#      'end_char': '111'},
#     {'id': '15',
#      'text': 'іс',
#      'lemma': 'іс',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '112',
#      'end_char': '114'},
#     {'id': '16',
#      'text': 'жүргізу',
#      'lemma': 'жүр',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Case=Nom|VerbForm=Ger',
#      'start_char': '115',
#      'end_char': '122'},
#     {'id': '17',
#      'text': 'заңнамасын',
#      'lemma': 'заңнама',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Acc|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '123',
#      'end_char': '133'},
#     {'id': '18',
#      'text': 'жетілдіру',
#      'lemma': 'жетілдір',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Case=Nom|VerbForm=Ger',
#      'start_char': '134',
#      'end_char': '143'},
#     {'id': '19',
#      'text': 'және',
#      'lemma': 'және',
#      'pos': 'CCONJ',
#      'pos_finegrained': 'cnjcoo',
#      'feats': None,
#      'start_char': '144',
#      'end_char': '148'},
#     {'id': '20',
#      'text': 'жеке',
#      'lemma': 'жеке',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '149',
#      'end_char': '153'},
#     {'id': '21',
#      'text': 'адамның',
#      'lemma': 'адам',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Gen',
#      'start_char': '154',
#      'end_char': '161'},
#     {'id': '22',
#      'text': 'құқықтарын',
#      'lemma': 'құқық',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Acc|Number=Plur|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '162',
#      'end_char': '172'},
#     {'id': '23',
#      'text': 'қорғауды',
#      'lemma': 'қорғау',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Case=Acc|VerbForm=Ger',
#      'start_char': '173',
#      'end_char': '181'},
#     {'id': '24',
#      'text': 'күшейту',
#      'lemma': 'күшейт',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Case=Nom|VerbForm=Ger',
#      'start_char': '182',
#      'end_char': '189'},
#     {'id': '25',
#      'text': 'мәселелері',
#      'lemma': 'мәселе',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '190',
#      'end_char': '200'},
#     {'id': '26',
#      'text': 'бойынша',
#      'lemma': 'бойынша',
#      'pos': 'ADP',
#      'pos_finegrained': 'post',
#      'feats': None,
#      'start_char': '201',
#      'end_char': '208'},
#     {'id': '27',
#      'text': 'өзгерістер',
#      'lemma': 'өзгеріс',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number=Plur',
#      'start_char': '209',
#      'end_char': '219'},
#     {'id': '28',
#      'text': 'мен',
#      'lemma': 'мен',
#      'pos': 'CCONJ',
#      'pos_finegrained': 'cnjcoo',
#      'feats': None,
#      'start_char': '220',
#      'end_char': '223'},
#     {'id': '29',
#      'text': 'толықтырулар',
#      'lemma': 'толықтыру',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number=Plur',
#      'start_char': '224',
#      'end_char': '236'},
#     {'id': '30',
#      'text': 'енгізу',
#      'lemma': 'енгіз',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Case=Nom|VerbForm=Ger',
#      'start_char': '237',
#      'end_char': '243'},
#     {'id': '31',
#      'text': 'туралы',
#      'lemma': 'турал',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '244',
#      'end_char': '250'},
#     {'id': '32',
#      'text': '"',
#      'lemma': '"',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'sent',
#      'feats': None,
#      'start_char': '250',
#      'end_char': '251'},
#     {'id': '1',
#      'text': '2019',
#      'lemma': '2019',
#      'pos': 'NUM',
#      'pos_finegrained': 'num',
#      'feats': 'NumType=Ord',
#      'start_char': '0',
#      'end_char': '4'},
#     {'id': '2',
#      'text': 'жылы',
#      'lemma': 'жыл',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '5',
#      'end_char': '9'},
#     {'id': '3',
#      'text': '27',
#      'lemma': '27',
#      'pos': 'NUM',
#      'pos_finegrained': 'num',
#      'feats': 'NumType=Ord',
#      'start_char': '10',
#      'end_char': '12'},
#     {'id': '4',
#      'text': 'желтоқсанда',
#      'lemma': 'желтоқсан',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Loc',
#      'start_char': '13',
#      'end_char': '24'},
#     {'id': '5',
#      'text': 'Президент',
#      'lemma': 'президент',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '25',
#      'end_char': '34'},
#     {'id': '6',
#      'text': '"',
#      'lemma': '"',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'sent',
#      'feats': None,
#      'start_char': '35',
#      'end_char': '36'},
#     {'id': '7',
#      'text': 'Қазақстан',
#      'lemma': 'Қазақстан',
#      'pos': 'PROPN',
#      'pos_finegrained': 'np',
#      'feats': 'Case=Nom',
#      'start_char': '36',
#      'end_char': '45'},
#     {'id': '8',
#      'text': 'Республикасының',
#      'lemma': 'республика',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Gen|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '46',
#      'end_char': '61'},
#     {'id': '9',
#      'text': 'кейбір',
#      'lemma': 'кейбір',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '62',
#      'end_char': '68'},
#     {'id': '10',
#      'text': 'заңнамалық',
#      'lemma': 'заңнамалық',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '69',
#      'end_char': '79'},
#     {'id': '11',
#      'text': 'актілеріне',
#      'lemma': 'акт',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Ins|Number=Plur|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '80',
#      'end_char': '90'},
#     {'id': '12',
#      'text': 'қылмыстық',
#      'lemma': 'қылмыстық',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '91',
#      'end_char': '100'},
#     {'id': '13',
#      'text': ',',
#      'lemma': ',',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'cm',
#      'feats': None,
#      'start_char': '100',
#      'end_char': '101'},
#     {'id': '14',
#      'text': 'қылмыстық',
#      'lemma': 'қылмыстық',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '102',
#      'end_char': '111'},
#     {'id': '15',
#      'text': 'іс',
#      'lemma': 'іс',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '112',
#      'end_char': '114'},
#     {'id': '16',
#      'text': 'жүргізу',
#      'lemma': 'жүр',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Case=Nom|VerbForm=Ger',
#      'start_char': '115',
#      'end_char': '122'},
#     {'id': '17',
#      'text': 'заңнамасын',
#      'lemma': 'заңнама',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Acc|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '123',
#      'end_char': '133'},
#     {'id': '18',
#      'text': 'жетілдіру',
#      'lemma': 'жетілдір',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Case=Nom|VerbForm=Ger',
#      'start_char': '134',
#      'end_char': '143'},
#     {'id': '19',
#      'text': 'және',
#      'lemma': 'және',
#      'pos': 'CCONJ',
#      'pos_finegrained': 'cnjcoo',
#      'feats': None,
#      'start_char': '144',
#      'end_char': '148'},
#     {'id': '20',
#      'text': 'жеке',
#      'lemma': 'жеке',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '149',
#      'end_char': '153'},
#     {'id': '21',
#      'text': 'адамның',
#      'lemma': 'адам',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Gen',
#      'start_char': '154',
#      'end_char': '161'},
#     {'id': '22',
#      'text': 'құқықтарын',
#      'lemma': 'құқық',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Acc|Number=Plur|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '162',
#      'end_char': '172'},
#     {'id': '23',
#      'text': 'қорғауды',
#      'lemma': 'қорғау',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Case=Acc|VerbForm=Ger',
#      'start_char': '173',
#      'end_char': '181'},
#     {'id': '24',
#      'text': 'күшейту',
#      'lemma': 'күшейт',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Case=Nom|VerbForm=Ger',
#      'start_char': '182',
#      'end_char': '189'},
#     {'id': '25',
#      'text': 'мәселелері',
#      'lemma': 'мәселе',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '190',
#      'end_char': '200'},
#     {'id': '26',
#      'text': 'бойынша',
#      'lemma': 'бойынша',
#      'pos': 'ADP',
#      'pos_finegrained': 'post',
#      'feats': None,
#      'start_char': '201',
#      'end_char': '208'},
#     {'id': '27',
#      'text': 'өзгерістер',
#      'lemma': 'өзгеріс',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number=Plur',
#      'start_char': '209',
#      'end_char': '219'},
#     {'id': '28',
#      'text': 'мен',
#      'lemma': 'мен',
#      'pos': 'CCONJ',
#      'pos_finegrained': 'cnjcoo',
#      'feats': None,
#      'start_char': '220',
#      'end_char': '223'},
#     {'id': '29',
#      'text': 'толықтырулар',
#      'lemma': 'толықтыру',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number=Plur',
#      'start_char': '224',
#      'end_char': '236'},
#     {'id': '30',
#      'text': 'енгізу',
#      'lemma': 'енгіз',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Case=Nom|VerbForm=Ger',
#      'start_char': '237',
#      'end_char': '243'},
#     {'id': '31',
#      'text': 'туралы',
#      'lemma': 'турал',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '244',
#      'end_char': '250'},
#     {'id': '32',
#      'text': '"',
#      'lemma': '"',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'sent',
#      'feats': None,
#      'start_char': '250',
#      'end_char': '251'},
#     {'id': '1',
#      'text': 'Заңға',
#      'lemma': 'заң',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Dat',
#      'start_char': '252',
#      'end_char': '257'},
#     {'id': '2',
#      'text': 'қол',
#      'lemma': 'қол',
#      'pos': 'X',
#      'pos_finegrained': 'x',
#      'feats': None,
#      'start_char': '258',
#      'end_char': '261'},
#     {'id': '3',
#      'text': 'қойды',
#      'lemma': 'қой',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin',
#      'start_char': '262',
#      'end_char': '267'},
#     {'id': '4',
#      'text': '.',
#      'lemma': '.',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'sent',
#      'feats': None,
#      'start_char': '267',
#      'end_char': '268'}]},
#   {'sentence_text': 'Кремль өкілінің айтуынша, Беларусь президенті Александр Лукашенко Путинге Минск Ресей мен Украина арасындағы келіссөз жүргізу процесі үшін барлық қажетті жағдай жасауға дайын екеніне сендірді, деп хабарлайды ТАСС.',
#    'tokens': [{'id': '1',
#      'text': 'Кремль',
#      'lemma': 'Кремль',
#      'pos': 'PROPN',
#      'pos_finegrained': 'np',
#      'feats': 'Case=Nom',
#      'start_char': '0',
#      'end_char': '6'},
#     {'id': '2',
#      'text': 'өкілінің',
#      'lemma': 'өкіл',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Gen|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '7',
#      'end_char': '15'},
#     {'id': '3',
#      'text': 'айтуынша',
#      'lemma': 'айтыу',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Loc|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '16',
#      'end_char': '24'},
#     {'id': '4',
#      'text': ',',
#      'lemma': ',',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'cm',
#      'feats': None,
#      'start_char': '24',
#      'end_char': '25'},
#     {'id': '5',
#      'text': 'Беларусь',
#      'lemma': 'Беларусь',
#      'pos': 'PROPN',
#      'pos_finegrained': 'np',
#      'feats': 'Case=Nom',
#      'start_char': '26',
#      'end_char': '34'},
#     {'id': '6',
#      'text': 'президенті',
#      'lemma': 'президент',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '35',
#      'end_char': '45'},
#     {'id': '1',
#      'text': 'Кремль',
#      'lemma': 'Кремль',
#      'pos': 'PROPN',
#      'pos_finegrained': 'np',
#      'feats': 'Case=Nom',
#      'start_char': '0',
#      'end_char': '6'},
#     {'id': '2',
#      'text': 'өкілінің',
#      'lemma': 'өкіл',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Gen|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '7',
#      'end_char': '15'},
#     {'id': '3',
#      'text': 'айтуынша',
#      'lemma': 'айтыу',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Loc|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '16',
#      'end_char': '24'},
#     {'id': '4',
#      'text': ',',
#      'lemma': ',',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'cm',
#      'feats': None,
#      'start_char': '24',
#      'end_char': '25'},
#     {'id': '5',
#      'text': 'Беларусь',
#      'lemma': 'Беларусь',
#      'pos': 'PROPN',
#      'pos_finegrained': 'np',
#      'feats': 'Case=Nom',
#      'start_char': '26',
#      'end_char': '34'},
#     {'id': '6',
#      'text': 'президенті',
#      'lemma': 'президент',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '35',
#      'end_char': '45'},
#     {'id': '1',
#      'text': 'Александр',
#      'lemma': 'Александр',
#      'pos': 'PROPN',
#      'pos_finegrained': 'np',
#      'feats': 'Case=Nom|Gender=Masc',
#      'start_char': '46',
#      'end_char': '55'},
#     {'id': '2',
#      'text': 'Лукашенко',
#      'lemma': 'Лукашенко',
#      'pos': 'PROPN',
#      'pos_finegrained': 'np',
#      'feats': 'Case=Nom|Gender=Masc',
#      'start_char': '56',
#      'end_char': '65'},
#     {'id': '3',
#      'text': 'Путинге',
#      'lemma': 'Путин',
#      'pos': 'PROPN',
#      'pos_finegrained': 'np',
#      'feats': 'Case=Dat',
#      'start_char': '66',
#      'end_char': '73'},
#     {'id': '4',
#      'text': 'Минск',
#      'lemma': 'Минск',
#      'pos': 'PROPN',
#      'pos_finegrained': 'np',
#      'feats': 'Case=Nom',
#      'start_char': '74',
#      'end_char': '79'},
#     {'id': '5',
#      'text': 'Ресей',
#      'lemma': 'Ресей',
#      'pos': 'PROPN',
#      'pos_finegrained': 'np',
#      'feats': 'Case=Nom',
#      'start_char': '80',
#      'end_char': '85'},
#     {'id': '6',
#      'text': 'мен',
#      'lemma': 'мен',
#      'pos': 'CCONJ',
#      'pos_finegrained': 'cnjcoo',
#      'feats': None,
#      'start_char': '86',
#      'end_char': '89'},
#     {'id': '7',
#      'text': 'Украина',
#      'lemma': 'Украина',
#      'pos': 'PROPN',
#      'pos_finegrained': 'np',
#      'feats': 'Case=Nom',
#      'start_char': '90',
#      'end_char': '97'},
#     {'id': '8',
#      'text': 'арасындағы',
#      'lemma': 'ара',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Loc|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '98',
#      'end_char': '108'},
#     {'id': '9',
#      'text': 'келіссөз',
#      'lemma': 'келіссөз',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '109',
#      'end_char': '117'},
#     {'id': '10',
#      'text': 'жүргізу',
#      'lemma': 'жүр',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Case=Nom|VerbForm=Ger',
#      'start_char': '118',
#      'end_char': '125'},
#     {'id': '11',
#      'text': 'процесі',
#      'lemma': 'проце',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '126',
#      'end_char': '133'},
#     {'id': '12',
#      'text': 'үшін',
#      'lemma': 'үшін',
#      'pos': 'ADP',
#      'pos_finegrained': 'post',
#      'feats': None,
#      'start_char': '134',
#      'end_char': '138'},
#     {'id': '13',
#      'text': 'барлық',
#      'lemma': 'барлық',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '139',
#      'end_char': '145'},
#     {'id': '14',
#      'text': 'қажетті',
#      'lemma': 'қажетті',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '146',
#      'end_char': '153'},
#     {'id': '15',
#      'text': 'жағдай',
#      'lemma': 'жағдай',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '154',
#      'end_char': '160'},
#     {'id': '16',
#      'text': 'жасауға',
#      'lemma': 'жаса',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Case=Dat|VerbForm=Ger',
#      'start_char': '161',
#      'end_char': '168'},
#     {'id': '17',
#      'text': 'дайын',
#      'lemma': 'дайын',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '169',
#      'end_char': '174'},
#     {'id': '18',
#      'text': 'екеніне',
#      'lemma': 'е',
#      'pos': 'AUX',
#      'pos_finegrained': 'cop',
#      'feats': 'Case=Dat|Number[psor]=Plur,Sing|Person[psor]=3|Tense=Past|VerbForm=Ger',
#      'start_char': '175',
#      'end_char': '182'},
#     {'id': '19',
#      'text': 'сендірді',
#      'lemma': 'сендір',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin',
#      'start_char': '183',
#      'end_char': '191'},
#     {'id': '20',
#      'text': ',',
#      'lemma': ',',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'cm',
#      'feats': None,
#      'start_char': '191',
#      'end_char': '192'},
#     {'id': '21',
#      'text': 'деп',
#      'lemma': 'де',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Aspect=Perf|VerbForm=Conv',
#      'start_char': '193',
#      'end_char': '196'},
#     {'id': '22',
#      'text': 'хабарлайды',
#      'lemma': 'хабарла',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Tense=Past|VerbForm=Fin',
#      'start_char': '197',
#      'end_char': '207'},
#     {'id': '23',
#      'text': 'ТАСС',
#      'lemma': 'ТАСС',
#      'pos': 'PROPN',
#      'pos_finegrained': 'np',
#      'feats': 'Case=Nom',
#      'start_char': '208',
#      'end_char': '212'},
#     {'id': '24',
#      'text': '.',
#      'lemma': '.',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'sent',
#      'feats': None,
#      'start_char': '212',
#      'end_char': '213'}]},
#   {'sentence_text': 'Биіктігі - 130 метр.Оның ішінде сол жақтағы мұнара ішінен лифт арқылы жоғары көтеріліп, қаланы биіктен тамашалауға болады.',
#    'tokens': [{'id': '1',
#      'text': 'Биіктігі',
#      'lemma': 'биіктік',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '0',
#      'end_char': '8'},
#     {'id': '2',
#      'text': '-',
#      'lemma': '-',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'guio',
#      'feats': None,
#      'start_char': '9',
#      'end_char': '10'},
#     {'id': '3',
#      'text': '130',
#      'lemma': '130',
#      'pos': 'NUM',
#      'pos_finegrained': 'num',
#      'feats': 'NumType=Card',
#      'start_char': '11',
#      'end_char': '14'},
#     {'id': '4',
#      'text': 'метр',
#      'lemma': 'метр',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '15',
#      'end_char': '19'},
#     {'id': '5',
#      'text': '.',
#      'lemma': '.',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'sent',
#      'feats': None,
#      'start_char': '19',
#      'end_char': '20'},
#     {'id': '1',
#      'text': 'Биіктігі',
#      'lemma': 'биіктік',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '0',
#      'end_char': '8'},
#     {'id': '2',
#      'text': '-',
#      'lemma': '-',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'guio',
#      'feats': None,
#      'start_char': '9',
#      'end_char': '10'},
#     {'id': '3',
#      'text': '130',
#      'lemma': '130',
#      'pos': 'NUM',
#      'pos_finegrained': 'num',
#      'feats': 'NumType=Card',
#      'start_char': '11',
#      'end_char': '14'},
#     {'id': '4',
#      'text': 'метр',
#      'lemma': 'метр',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '15',
#      'end_char': '19'},
#     {'id': '5',
#      'text': '.',
#      'lemma': '.',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'sent',
#      'feats': None,
#      'start_char': '19',
#      'end_char': '20'},
#     {'id': '1',
#      'text': 'Оның',
#      'lemma': 'ол',
#      'pos': 'PRON',
#      'pos_finegrained': 'prn',
#      'feats': 'Case=Gen|Number=Sing|Person=3|PronType=Prs',
#      'start_char': '20',
#      'end_char': '24'},
#     {'id': '2',
#      'text': 'ішінде',
#      'lemma': 'іш',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Loc|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '25',
#      'end_char': '31'},
#     {'id': '3',
#      'text': 'сол',
#      'lemma': 'сол',
#      'pos': 'DET',
#      'pos_finegrained': 'det',
#      'feats': 'PronType=Dem',
#      'start_char': '32',
#      'end_char': '35'},
#     {'id': '4',
#      'text': 'жақтағы',
#      'lemma': 'жақ',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Loc',
#      'start_char': '36',
#      'end_char': '43'},
#     {'id': '5',
#      'text': 'мұнара',
#      'lemma': 'мұнара',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '44',
#      'end_char': '50'},
#     {'id': '6',
#      'text': 'ішінен',
#      'lemma': 'іш',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Abl|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '51',
#      'end_char': '57'},
#     {'id': '7',
#      'text': 'лифт',
#      'lemma': 'лифт',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '58',
#      'end_char': '62'},
#     {'id': '8',
#      'text': 'арқылы',
#      'lemma': 'арқылы',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Loc|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '63',
#      'end_char': '69'},
#     {'id': '9',
#      'text': 'жоғары',
#      'lemma': 'жоғары',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '70',
#      'end_char': '76'},
#     {'id': '10',
#      'text': 'көтеріліп',
#      'lemma': 'көтер',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Aspect=Perf|VerbForm=Conv',
#      'start_char': '77',
#      'end_char': '86'},
#     {'id': '11',
#      'text': ',',
#      'lemma': ',',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'cm',
#      'feats': None,
#      'start_char': '86',
#      'end_char': '87'},
#     {'id': '12',
#      'text': 'қаланы',
#      'lemma': 'қала',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Acc',
#      'start_char': '88',
#      'end_char': '94'},
#     {'id': '13',
#      'text': 'биіктен',
#      'lemma': 'биік',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Abl',
#      'start_char': '95',
#      'end_char': '102'},
#     {'id': '14',
#      'text': 'тамашалауға',
#      'lemma': 'тамаша',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Case=Dat|VerbForm=Ger',
#      'start_char': '103',
#      'end_char': '114'},
#     {'id': '15',
#      'text': 'болады',
#      'lemma': 'бол',
#      'pos': 'AUX',
#      'pos_finegrained': 'v',
#      'feats': 'Aspect=Hab|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#      'start_char': '115',
#      'end_char': '121'},
#     {'id': '16',
#      'text': '.',
#      'lemma': '.',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'sent',
#      'feats': None,
#      'start_char': '121',
#      'end_char': '122'}]},
#   {'sentence_text': 'Атап айтқанда, картоп қоры 380 мың тоннаны құрайды, ерте егін болжамы 170 мың тоннадан асады; 32 мың тонна қырыққабат сақталуда.',
#    'tokens': [{'id': '1',
#      'text': 'Атап',
#      'lemma': 'Атап',
#      'pos': 'X',
#      'pos_finegrained': 'x',
#      'feats': None,
#      'start_char': '0',
#      'end_char': '4'},
#     {'id': '2',
#      'text': 'айтқанда',
#      'lemma': 'айт',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Tense=Past|VerbForm=Part',
#      'start_char': '5',
#      'end_char': '13'},
#     {'id': '3',
#      'text': ',',
#      'lemma': ',',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'cm',
#      'feats': None,
#      'start_char': '13',
#      'end_char': '14'},
#     {'id': '4',
#      'text': 'картоп',
#      'lemma': 'картоп',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '15',
#      'end_char': '21'},
#     {'id': '5',
#      'text': 'қоры',
#      'lemma': 'қор',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '22',
#      'end_char': '26'},
#     {'id': '6',
#      'text': '380',
#      'lemma': '380',
#      'pos': 'NUM',
#      'pos_finegrained': 'num',
#      'feats': 'NumType=Card',
#      'start_char': '27',
#      'end_char': '30'},
#     {'id': '7',
#      'text': 'мың',
#      'lemma': 'мың',
#      'pos': 'NUM',
#      'pos_finegrained': 'num',
#      'feats': 'NumType=Card',
#      'start_char': '31',
#      'end_char': '34'},
#     {'id': '8',
#      'text': 'тоннаны',
#      'lemma': 'тоннан',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Acc',
#      'start_char': '35',
#      'end_char': '42'},
#     {'id': '9',
#      'text': 'құрайды',
#      'lemma': 'құра',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Aspect=Hab|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#      'start_char': '43',
#      'end_char': '50'},
#     {'id': '10',
#      'text': ',',
#      'lemma': ',',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'cm',
#      'feats': None,
#      'start_char': '50',
#      'end_char': '51'},
#     {'id': '11',
#      'text': 'ерте',
#      'lemma': 'ерте',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '52',
#      'end_char': '56'},
#     {'id': '12',
#      'text': 'егін',
#      'lemma': 'ег',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '57',
#      'end_char': '61'},
#     {'id': '13',
#      'text': 'болжамы',
#      'lemma': 'болжам',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '62',
#      'end_char': '69'},
#     {'id': '14',
#      'text': '170',
#      'lemma': '170',
#      'pos': 'NUM',
#      'pos_finegrained': 'num',
#      'feats': 'NumType=Card',
#      'start_char': '70',
#      'end_char': '73'},
#     {'id': '15',
#      'text': 'мың',
#      'lemma': 'мың',
#      'pos': 'NUM',
#      'pos_finegrained': 'num',
#      'feats': 'NumType=Card',
#      'start_char': '74',
#      'end_char': '77'},
#     {'id': '16',
#      'text': 'тоннадан',
#      'lemma': 'тонна',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Abl',
#      'start_char': '78',
#      'end_char': '86'},
#     {'id': '17',
#      'text': 'асады',
#      'lemma': 'аса',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Aspect=Hab|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#      'start_char': '87',
#      'end_char': '92'},
#     {'id': '18',
#      'text': ';',
#      'lemma': ';',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'sent',
#      'feats': None,
#      'start_char': '92',
#      'end_char': '93'},
#     {'id': '1',
#      'text': 'Атап',
#      'lemma': 'Атап',
#      'pos': 'X',
#      'pos_finegrained': 'x',
#      'feats': None,
#      'start_char': '0',
#      'end_char': '4'},
#     {'id': '2',
#      'text': 'айтқанда',
#      'lemma': 'айт',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Tense=Past|VerbForm=Part',
#      'start_char': '5',
#      'end_char': '13'},
#     {'id': '3',
#      'text': ',',
#      'lemma': ',',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'cm',
#      'feats': None,
#      'start_char': '13',
#      'end_char': '14'},
#     {'id': '4',
#      'text': 'картоп',
#      'lemma': 'картоп',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '15',
#      'end_char': '21'},
#     {'id': '5',
#      'text': 'қоры',
#      'lemma': 'қор',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '22',
#      'end_char': '26'},
#     {'id': '6',
#      'text': '380',
#      'lemma': '380',
#      'pos': 'NUM',
#      'pos_finegrained': 'num',
#      'feats': 'NumType=Card',
#      'start_char': '27',
#      'end_char': '30'},
#     {'id': '7',
#      'text': 'мың',
#      'lemma': 'мың',
#      'pos': 'NUM',
#      'pos_finegrained': 'num',
#      'feats': 'NumType=Card',
#      'start_char': '31',
#      'end_char': '34'},
#     {'id': '8',
#      'text': 'тоннаны',
#      'lemma': 'тоннан',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Acc',
#      'start_char': '35',
#      'end_char': '42'},
#     {'id': '9',
#      'text': 'құрайды',
#      'lemma': 'құра',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Aspect=Hab|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#      'start_char': '43',
#      'end_char': '50'},
#     {'id': '10',
#      'text': ',',
#      'lemma': ',',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'cm',
#      'feats': None,
#      'start_char': '50',
#      'end_char': '51'},
#     {'id': '11',
#      'text': 'ерте',
#      'lemma': 'ерте',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '52',
#      'end_char': '56'},
#     {'id': '12',
#      'text': 'егін',
#      'lemma': 'ег',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '57',
#      'end_char': '61'},
#     {'id': '13',
#      'text': 'болжамы',
#      'lemma': 'болжам',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '62',
#      'end_char': '69'},
#     {'id': '14',
#      'text': '170',
#      'lemma': '170',
#      'pos': 'NUM',
#      'pos_finegrained': 'num',
#      'feats': 'NumType=Card',
#      'start_char': '70',
#      'end_char': '73'},
#     {'id': '15',
#      'text': 'мың',
#      'lemma': 'мың',
#      'pos': 'NUM',
#      'pos_finegrained': 'num',
#      'feats': 'NumType=Card',
#      'start_char': '74',
#      'end_char': '77'},
#     {'id': '16',
#      'text': 'тоннадан',
#      'lemma': 'тонна',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Abl',
#      'start_char': '78',
#      'end_char': '86'},
#     {'id': '17',
#      'text': 'асады',
#      'lemma': 'аса',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Aspect=Hab|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#      'start_char': '87',
#      'end_char': '92'},
#     {'id': '18',
#      'text': ';',
#      'lemma': ';',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'sent',
#      'feats': None,
#      'start_char': '92',
#      'end_char': '93'},
#     {'id': '1',
#      'text': '32',
#      'lemma': '32',
#      'pos': 'NUM',
#      'pos_finegrained': 'num',
#      'feats': 'NumType=Card',
#      'start_char': '94',
#      'end_char': '96'},
#     {'id': '2',
#      'text': 'мың',
#      'lemma': 'мың',
#      'pos': 'NUM',
#      'pos_finegrained': 'num',
#      'feats': 'NumType=Card',
#      'start_char': '97',
#      'end_char': '100'},
#     {'id': '3',
#      'text': 'тонна',
#      'lemma': 'тон',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '101',
#      'end_char': '106'},
#     {'id': '4',
#      'text': 'қырыққабат',
#      'lemma': 'қырыққабат',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '107',
#      'end_char': '117'},
#     {'id': '5',
#      'text': 'сақталуда',
#      'lemma': 'сақта',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin|Voice=Pass',
#      'start_char': '118',
#      'end_char': '127'},
#     {'id': '6',
#      'text': '.',
#      'lemma': '.',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'sent',
#      'feats': None,
#      'start_char': '127',
#      'end_char': '128'}]},
#   {'sentence_text': 'Бұл олқылықтың орнын толтыру мақсатында Солтүстік Қазақстан көлік прокуратурасы "Халықаралық медиация орталығы" РҚБ СҚО бойынша өкілі Алтын би Бесембаевамен меморандумға отырды.',
#    'tokens': [{'id': '1',
#      'text': 'Бұл',
#      'lemma': 'бұл',
#      'pos': 'DET',
#      'pos_finegrained': 'det',
#      'feats': 'PronType=Dem',
#      'start_char': '0',
#      'end_char': '3'},
#     {'id': '2',
#      'text': 'олқылықтың',
#      'lemma': 'олқылық',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Gen',
#      'start_char': '4',
#      'end_char': '14'},
#     {'id': '3',
#      'text': 'орнын',
#      'lemma': 'орнын',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Acc|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '15',
#      'end_char': '20'},
#     {'id': '4',
#      'text': 'толтыру',
#      'lemma': 'толтыр',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Case=Nom|VerbForm=Ger',
#      'start_char': '21',
#      'end_char': '28'},
#     {'id': '5',
#      'text': 'мақсатында',
#      'lemma': 'мақсат',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Loc|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '29',
#      'end_char': '39'},
#     {'id': '6',
#      'text': 'Солтүстік',
#      'lemma': 'солтүстік',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '40',
#      'end_char': '49'},
#     {'id': '7',
#      'text': 'Қазақстан',
#      'lemma': 'Қазақстан',
#      'pos': 'PROPN',
#      'pos_finegrained': 'np',
#      'feats': 'Case=Nom',
#      'start_char': '50',
#      'end_char': '59'},
#     {'id': '8',
#      'text': 'көлік',
#      'lemma': 'көлік',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '60',
#      'end_char': '65'},
#     {'id': '9',
#      'text': 'прокуратурасы',
#      'lemma': 'прокуратура',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '66',
#      'end_char': '79'},
#     {'id': '10',
#      'text': '"',
#      'lemma': '"',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'sent',
#      'feats': None,
#      'start_char': '80',
#      'end_char': '81'},
#     {'id': '11',
#      'text': 'Халықаралық',
#      'lemma': 'халықаралық',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '81',
#      'end_char': '92'},
#     {'id': '12',
#      'text': 'медиация',
#      'lemma': 'медиация',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '93',
#      'end_char': '101'},
#     {'id': '13',
#      'text': 'орталығы',
#      'lemma': 'орталық',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '102',
#      'end_char': '110'},
#     {'id': '14',
#      'text': '"',
#      'lemma': '"',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'sent',
#      'feats': None,
#      'start_char': '110',
#      'end_char': '111'},
#     {'id': '1',
#      'text': 'Бұл',
#      'lemma': 'бұл',
#      'pos': 'DET',
#      'pos_finegrained': 'det',
#      'feats': 'PronType=Dem',
#      'start_char': '0',
#      'end_char': '3'},
#     {'id': '2',
#      'text': 'олқылықтың',
#      'lemma': 'олқылық',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Gen',
#      'start_char': '4',
#      'end_char': '14'},
#     {'id': '3',
#      'text': 'орнын',
#      'lemma': 'орнын',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Acc|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '15',
#      'end_char': '20'},
#     {'id': '4',
#      'text': 'толтыру',
#      'lemma': 'толтыр',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Case=Nom|VerbForm=Ger',
#      'start_char': '21',
#      'end_char': '28'},
#     {'id': '5',
#      'text': 'мақсатында',
#      'lemma': 'мақсат',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Loc|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '29',
#      'end_char': '39'},
#     {'id': '6',
#      'text': 'Солтүстік',
#      'lemma': 'солтүстік',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '40',
#      'end_char': '49'},
#     {'id': '7',
#      'text': 'Қазақстан',
#      'lemma': 'Қазақстан',
#      'pos': 'PROPN',
#      'pos_finegrained': 'np',
#      'feats': 'Case=Nom',
#      'start_char': '50',
#      'end_char': '59'},
#     {'id': '8',
#      'text': 'көлік',
#      'lemma': 'көлік',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '60',
#      'end_char': '65'},
#     {'id': '9',
#      'text': 'прокуратурасы',
#      'lemma': 'прокуратура',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '66',
#      'end_char': '79'},
#     {'id': '10',
#      'text': '"',
#      'lemma': '"',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'sent',
#      'feats': None,
#      'start_char': '80',
#      'end_char': '81'},
#     {'id': '11',
#      'text': 'Халықаралық',
#      'lemma': 'халықаралық',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '81',
#      'end_char': '92'},
#     {'id': '12',
#      'text': 'медиация',
#      'lemma': 'медиация',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '93',
#      'end_char': '101'},
#     {'id': '13',
#      'text': 'орталығы',
#      'lemma': 'орталық',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '102',
#      'end_char': '110'},
#     {'id': '14',
#      'text': '"',
#      'lemma': '"',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'sent',
#      'feats': None,
#      'start_char': '110',
#      'end_char': '111'},
#     {'id': '1',
#      'text': 'РҚБ',
#      'lemma': 'РҚБ',
#      'pos': 'PROPN',
#      'pos_finegrained': 'np',
#      'feats': 'Case=Nom',
#      'start_char': '112',
#      'end_char': '115'},
#     {'id': '2',
#      'text': 'СҚО',
#      'lemma': 'СҚО',
#      'pos': 'PROPN',
#      'pos_finegrained': 'np',
#      'feats': 'Case=Nom',
#      'start_char': '116',
#      'end_char': '119'},
#     {'id': '3',
#      'text': 'бойынша',
#      'lemma': 'бойынша',
#      'pos': 'ADP',
#      'pos_finegrained': 'post',
#      'feats': None,
#      'start_char': '120',
#      'end_char': '127'},
#     {'id': '4',
#      'text': 'өкілі',
#      'lemma': 'өкіл',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '128',
#      'end_char': '133'},
#     {'id': '5',
#      'text': 'Алтын',
#      'lemma': 'алтын',
#      'pos': 'PROPN',
#      'pos_finegrained': 'np',
#      'feats': 'Case=Nom|Gender=Masc',
#      'start_char': '134',
#      'end_char': '139'},
#     {'id': '6',
#      'text': 'би',
#      'lemma': 'би',
#      'pos': 'PROPN',
#      'pos_finegrained': 'np',
#      'feats': 'Case=Nom|Gender=Masc',
#      'start_char': '140',
#      'end_char': '142'},
#     {'id': '7',
#      'text': 'Бесембаевамен',
#      'lemma': 'Бесембаев',
#      'pos': 'PROPN',
#      'pos_finegrained': 'np',
#      'feats': 'Case=Ins|Gender=Masc',
#      'start_char': '143',
#      'end_char': '156'},
#     {'id': '8',
#      'text': 'меморандумға',
#      'lemma': 'меморанду',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Dat',
#      'start_char': '157',
#      'end_char': '169'},
#     {'id': '9',
#      'text': 'отырды',
#      'lemma': 'отыр',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin',
#      'start_char': '170',
#      'end_char': '176'},
#     {'id': '10',
#      'text': '.',
#      'lemma': '.',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'sent',
#      'feats': None,
#      'start_char': '176',
#      'end_char': '177'}]},
#   {'sentence_text': 'Сонымен қатар, 2022 жылдың қыркүйегінен бастап "кейбір заңнамалық актілерге сақтандыру нарығын және бағалы қағаздар нарығын реттеу мен дамыту мәселелері бойынша өзгерістер мен толықтырулар енгізу туралы" ҚР Заңы аясында өмірді сақтандырудың жаңа әлеуметтік маңызды өнімі - бірлескен зейнетақы аннуитеті енгізілді.',
#    'tokens': [{'id': '1',
#      'text': 'Сонымен',
#      'lemma': 'сонымен',
#      'pos': 'PRON',
#      'pos_finegrained': 'prn',
#      'feats': 'Case=Ins|PronType=Dem',
#      'start_char': '0',
#      'end_char': '7'},
#     {'id': '2',
#      'text': 'қатар',
#      'lemma': 'қатар',
#      'pos': 'ADP',
#      'pos_finegrained': 'post',
#      'feats': None,
#      'start_char': '8',
#      'end_char': '13'},
#     {'id': '3',
#      'text': ',',
#      'lemma': ',',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'cm',
#      'feats': None,
#      'start_char': '13',
#      'end_char': '14'},
#     {'id': '4',
#      'text': '2022',
#      'lemma': '2022',
#      'pos': 'NUM',
#      'pos_finegrained': 'num',
#      'feats': 'NumType=Ord',
#      'start_char': '15',
#      'end_char': '19'},
#     {'id': '5',
#      'text': 'жылдың',
#      'lemma': 'жыл',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Gen',
#      'start_char': '20',
#      'end_char': '26'},
#     {'id': '6',
#      'text': 'қыркүйегінен',
#      'lemma': 'қыркүйек',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Abl|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '27',
#      'end_char': '39'},
#     {'id': '7',
#      'text': 'бастап',
#      'lemma': 'баста',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Aspect=Perf|VerbForm=Conv',
#      'start_char': '40',
#      'end_char': '46'},
#     {'id': '8',
#      'text': '"',
#      'lemma': '"',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'sent',
#      'feats': None,
#      'start_char': '47',
#      'end_char': '48'},
#     {'id': '9',
#      'text': 'кейбір',
#      'lemma': 'кейбір',
#      'pos': 'DET',
#      'pos_finegrained': 'det',
#      'feats': 'PronType=Tot',
#      'start_char': '48',
#      'end_char': '54'},
#     {'id': '10',
#      'text': 'заңнамалық',
#      'lemma': 'заңнамалық',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '55',
#      'end_char': '65'},
#     {'id': '11',
#      'text': 'актілерге',
#      'lemma': 'акт',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Dat|Number=Plur',
#      'start_char': '66',
#      'end_char': '75'},
#     {'id': '12',
#      'text': 'сақтандыру',
#      'lemma': 'сақтандыру',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '76',
#      'end_char': '86'},
#     {'id': '13',
#      'text': 'нарығын',
#      'lemma': 'нарық',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Acc|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '87',
#      'end_char': '94'},
#     {'id': '14',
#      'text': 'және',
#      'lemma': 'және',
#      'pos': 'CCONJ',
#      'pos_finegrained': 'cnjcoo',
#      'feats': None,
#      'start_char': '95',
#      'end_char': '99'},
#     {'id': '15',
#      'text': 'бағалы',
#      'lemma': 'бағалы',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '100',
#      'end_char': '106'},
#     {'id': '16',
#      'text': 'қағаздар',
#      'lemma': 'қағаз',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number=Plur',
#      'start_char': '107',
#      'end_char': '115'},
#     {'id': '17',
#      'text': 'нарығын',
#      'lemma': 'нарық',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Acc|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '116',
#      'end_char': '123'},
#     {'id': '18',
#      'text': 'реттеу',
#      'lemma': 'ретте',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Case=Nom|VerbForm=Ger',
#      'start_char': '124',
#      'end_char': '130'},
#     {'id': '19',
#      'text': 'мен',
#      'lemma': 'мен',
#      'pos': 'CCONJ',
#      'pos_finegrained': 'cnjcoo',
#      'feats': None,
#      'start_char': '131',
#      'end_char': '134'},
#     {'id': '20',
#      'text': 'дамыту',
#      'lemma': 'дамыт',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Case=Nom|VerbForm=Ger',
#      'start_char': '135',
#      'end_char': '141'},
#     {'id': '21',
#      'text': 'мәселелері',
#      'lemma': 'мәселе',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number=Plur|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '142',
#      'end_char': '152'},
#     {'id': '22',
#      'text': 'бойынша',
#      'lemma': 'бойынша',
#      'pos': 'ADP',
#      'pos_finegrained': 'post',
#      'feats': None,
#      'start_char': '153',
#      'end_char': '160'},
#     {'id': '23',
#      'text': 'өзгерістер',
#      'lemma': 'өзгеріс',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number=Plur',
#      'start_char': '161',
#      'end_char': '171'},
#     {'id': '24',
#      'text': 'мен',
#      'lemma': 'мен',
#      'pos': 'CCONJ',
#      'pos_finegrained': 'cnjcoo',
#      'feats': None,
#      'start_char': '172',
#      'end_char': '175'},
#     {'id': '25',
#      'text': 'толықтырулар',
#      'lemma': 'толықтыру',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number=Plur',
#      'start_char': '176',
#      'end_char': '188'},
#     {'id': '26',
#      'text': 'енгізу',
#      'lemma': 'енгіз',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Case=Nom|VerbForm=Ger',
#      'start_char': '189',
#      'end_char': '195'},
#     {'id': '27',
#      'text': 'туралы',
#      'lemma': 'турал',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '196',
#      'end_char': '202'},
#     {'id': '28',
#      'text': '"',
#      'lemma': '"',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'sent',
#      'feats': None,
#      'start_char': '202',
#      'end_char': '203'},
#     {'id': '1',
#      'text': 'Сонымен',
#      'lemma': 'сонымен',
#      'pos': 'PRON',
#      'pos_finegrained': 'prn',
#      'feats': 'Case=Ins|PronType=Dem',
#      'start_char': '0',
#      'end_char': '7'},
#     {'id': '2',
#      'text': 'қатар',
#      'lemma': 'қатар',
#      'pos': 'ADP',
#      'pos_finegrained': 'post',
#      'feats': None,
#      'start_char': '8',
#      'end_char': '13'},
#     {'id': '3',
#      'text': ',',
#      'lemma': ',',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'cm',
#      'feats': None,
#      'start_char': '13',
#      'end_char': '14'},
#     {'id': '4',
#      'text': '2022',
#      'lemma': '2022',
#      'pos': 'NUM',
#      'pos_finegrained': 'num',
#      'feats': 'NumType=Ord',
#      'start_char': '15',
#      'end_char': '19'},
#     {'id': '5',
#      'text': 'жылдың',
#      'lemma': 'жыл',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Gen',
#      'start_char': '20',
#      'end_char': '26'},
#     {'id': '6',
#      'text': 'қыркүйегінен',
#      'lemma': 'қыркүйек',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Abl|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '27',
#      'end_char': '39'},
#     {'id': '7',
#      'text': 'бастап',
#      'lemma': 'баста',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Aspect=Perf|VerbForm=Conv',
#      'start_char': '40',
#      'end_char': '46'},
#     {'id': '8',
#      'text': '"',
#      'lemma': '"',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'sent',
#      'feats': None,
#      'start_char': '47',
#      'end_char': '48'},
#     {'id': '9',
#      'text': 'кейбір',
#      'lemma': 'кейбір',
#      'pos': 'DET',
#      'pos_finegrained': 'det',
#      'feats': 'PronType=Tot',
#      'start_char': '48',
#      'end_char': '54'},
#     {'id': '10',
#      'text': 'заңнамалық',
#      'lemma': 'заңнамалық',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '55',
#      'end_char': '65'},
#     {'id': '11',
#      'text': 'актілерге',
#      'lemma': 'акт',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Dat|Number=Plur',
#      'start_char': '66',
#      'end_char': '75'},
#     {'id': '12',
#      'text': 'сақтандыру',
#      'lemma': 'сақтандыру',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '76',
#      'end_char': '86'},
#     {'id': '13',
#      'text': 'нарығын',
#      'lemma': 'нарық',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Acc|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '87',
#      'end_char': '94'},
#     {'id': '14',
#      'text': 'және',
#      'lemma': 'және',
#      'pos': 'CCONJ',
#      'pos_finegrained': 'cnjcoo',
#      'feats': None,
#      'start_char': '95',
#      'end_char': '99'},
#     {'id': '15',
#      'text': 'бағалы',
#      'lemma': 'бағалы',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '100',
#      'end_char': '106'},
#     {'id': '16',
#      'text': 'қағаздар',
#      'lemma': 'қағаз',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number=Plur',
#      'start_char': '107',
#      'end_char': '115'},
#     {'id': '17',
#      'text': 'нарығын',
#      'lemma': 'нарық',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Acc|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '116',
#      'end_char': '123'},
#     {'id': '18',
#      'text': 'реттеу',
#      'lemma': 'ретте',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Case=Nom|VerbForm=Ger',
#      'start_char': '124',
#      'end_char': '130'},
#     {'id': '19',
#      'text': 'мен',
#      'lemma': 'мен',
#      'pos': 'CCONJ',
#      'pos_finegrained': 'cnjcoo',
#      'feats': None,
#      'start_char': '131',
#      'end_char': '134'},
#     {'id': '20',
#      'text': 'дамыту',
#      'lemma': 'дамыт',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Case=Nom|VerbForm=Ger',
#      'start_char': '135',
#      'end_char': '141'},
#     {'id': '21',
#      'text': 'мәселелері',
#      'lemma': 'мәселе',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number=Plur|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '142',
#      'end_char': '152'},
#     {'id': '22',
#      'text': 'бойынша',
#      'lemma': 'бойынша',
#      'pos': 'ADP',
#      'pos_finegrained': 'post',
#      'feats': None,
#      'start_char': '153',
#      'end_char': '160'},
#     {'id': '23',
#      'text': 'өзгерістер',
#      'lemma': 'өзгеріс',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number=Plur',
#      'start_char': '161',
#      'end_char': '171'},
#     {'id': '24',
#      'text': 'мен',
#      'lemma': 'мен',
#      'pos': 'CCONJ',
#      'pos_finegrained': 'cnjcoo',
#      'feats': None,
#      'start_char': '172',
#      'end_char': '175'},
#     {'id': '25',
#      'text': 'толықтырулар',
#      'lemma': 'толықтыру',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number=Plur',
#      'start_char': '176',
#      'end_char': '188'},
#     {'id': '26',
#      'text': 'енгізу',
#      'lemma': 'енгіз',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Case=Nom|VerbForm=Ger',
#      'start_char': '189',
#      'end_char': '195'},
#     {'id': '27',
#      'text': 'туралы',
#      'lemma': 'турал',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '196',
#      'end_char': '202'},
#     {'id': '28',
#      'text': '"',
#      'lemma': '"',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'sent',
#      'feats': None,
#      'start_char': '202',
#      'end_char': '203'},
#     {'id': '1',
#      'text': 'ҚР',
#      'lemma': 'ҚР',
#      'pos': 'PROPN',
#      'pos_finegrained': 'np',
#      'feats': 'Case=Nom',
#      'start_char': '204',
#      'end_char': '206'},
#     {'id': '2',
#      'text': 'Заңы',
#      'lemma': 'заң',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '207',
#      'end_char': '211'},
#     {'id': '3',
#      'text': 'аясында',
#      'lemma': 'аяыс',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Loc|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '212',
#      'end_char': '219'},
#     {'id': '4',
#      'text': 'өмірді',
#      'lemma': 'өмірд',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Acc',
#      'start_char': '220',
#      'end_char': '226'},
#     {'id': '5',
#      'text': 'сақтандырудың',
#      'lemma': 'сақтандыр',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Gen',
#      'start_char': '227',
#      'end_char': '240'},
#     {'id': '6',
#      'text': 'жаңа',
#      'lemma': 'жаңа',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '241',
#      'end_char': '245'},
#     {'id': '7',
#      'text': 'әлеуметтік',
#      'lemma': 'әлеуметтік',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '246',
#      'end_char': '256'},
#     {'id': '8',
#      'text': 'маңызды',
#      'lemma': 'маңызды',
#      'pos': 'ADJ',
#      'pos_finegrained': 'adj',
#      'feats': None,
#      'start_char': '257',
#      'end_char': '264'},
#     {'id': '9',
#      'text': 'өнімі',
#      'lemma': 'өнім',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '265',
#      'end_char': '270'},
#     {'id': '10',
#      'text': '-',
#      'lemma': '-',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'guio',
#      'feats': None,
#      'start_char': '271',
#      'end_char': '272'},
#     {'id': '11',
#      'text': 'бірлескен',
#      'lemma': 'бірлес',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Tense=Past|VerbForm=Part',
#      'start_char': '273',
#      'end_char': '282'},
#     {'id': '12',
#      'text': 'зейнетақы',
#      'lemma': 'зейнетақ',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom',
#      'start_char': '283',
#      'end_char': '292'},
#     {'id': '13',
#      'text': 'аннуитеті',
#      'lemma': 'аннуитет',
#      'pos': 'NOUN',
#      'pos_finegrained': 'n',
#      'feats': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#      'start_char': '293',
#      'end_char': '302'},
#     {'id': '14',
#      'text': 'енгізілді',
#      'lemma': 'енгіз',
#      'pos': 'VERB',
#      'pos_finegrained': 'v',
#      'feats': 'Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin|Voice=Pass',
#      'start_char': '303',
#      'end_char': '312'},
#     {'id': '15',
#      'text': '.',
#      'lemma': '.',
#      'pos': 'PUNCT',
#      'pos_finegrained': 'sent',
#      'feats': None,
#      'start_char': '312',
#      'end_char': '313'}]}]}

# %%
# Define data classes using Pydantic

class Token(BaseModel):
    id: str
    text: str
    lemma: str
    pos: str
    pos_finegrained: str
    feats: str | None = None  # some tokens had feats value as None in the sample data file, therefore making str as optional
    start_char: str
    end_char: str

class Sentence(BaseModel):
    sentence_text: str
    tokens: list[Token]

# %%
# Process the input data
lemmas_frequency = defaultdict(int)
wordforms_frequency = defaultdict(int)

for sentence_data in input_data["sentences"]:
    sentence = Sentence(**sentence_data)
    for token in sentence.tokens:
        lemmas_frequency[token.lemma] += 1
        wordforms_frequency[token.text] += 1

# %%
output_data = {
    "lemmas": [
        {
            "lemma": lemma,
            "pos": token.pos,
            "inflection_info": token.feats,
            "total_frequency": frequency,
            "wordform_frequency": wordforms_frequency[token.text]
        }
        for lemma, frequency in lemmas_frequency.items()
        for token in sentence.tokens
        if token.lemma == lemma
    ]
}

# %%
output_data
# Out:
# {'lemmas': [{'lemma': 'жыл',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Gen',
#    'total_frequency': 4,
#    'wordform_frequency': 2},
#   {'lemma': 'жыл',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Gen',
#    'total_frequency': 4,
#    'wordform_frequency': 2},
#   {'lemma': '"',
#    'pos': 'PUNCT',
#    'inflection_info': None,
#    'total_frequency': 12,
#    'wordform_frequency': 12},
#   {'lemma': '"',
#    'pos': 'PUNCT',
#    'inflection_info': None,
#    'total_frequency': 12,
#    'wordform_frequency': 12},
#   {'lemma': '"',
#    'pos': 'PUNCT',
#    'inflection_info': None,
#    'total_frequency': 12,
#    'wordform_frequency': 12},
#   {'lemma': '"',
#    'pos': 'PUNCT',
#    'inflection_info': None,
#    'total_frequency': 12,
#    'wordform_frequency': 12},
#   {'lemma': 'кейбір',
#    'pos': 'DET',
#    'inflection_info': 'PronType=Tot',
#    'total_frequency': 4,
#    'wordform_frequency': 4},
#   {'lemma': 'кейбір',
#    'pos': 'DET',
#    'inflection_info': 'PronType=Tot',
#    'total_frequency': 4,
#    'wordform_frequency': 4},
#   {'lemma': 'заңнамалық',
#    'pos': 'ADJ',
#    'inflection_info': None,
#    'total_frequency': 4,
#    'wordform_frequency': 4},
#   {'lemma': 'заңнамалық',
#    'pos': 'ADJ',
#    'inflection_info': None,
#    'total_frequency': 4,
#    'wordform_frequency': 4},
#   {'lemma': 'акт',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Dat|Number=Plur',
#    'total_frequency': 4,
#    'wordform_frequency': 2},
#   {'lemma': 'акт',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Dat|Number=Plur',
#    'total_frequency': 4,
#    'wordform_frequency': 2},
#   {'lemma': ',',
#    'pos': 'PUNCT',
#    'inflection_info': None,
#    'total_frequency': 12,
#    'wordform_frequency': 12},
#   {'lemma': ',',
#    'pos': 'PUNCT',
#    'inflection_info': None,
#    'total_frequency': 12,
#    'wordform_frequency': 12},
#   {'lemma': 'және',
#    'pos': 'CCONJ',
#    'inflection_info': None,
#    'total_frequency': 4,
#    'wordform_frequency': 4},
#   {'lemma': 'және',
#    'pos': 'CCONJ',
#    'inflection_info': None,
#    'total_frequency': 4,
#    'wordform_frequency': 4},
#   {'lemma': 'мәселе',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Nom|Number=Plur|Number[psor]=Plur,Sing|Person[psor]=3',
#    'total_frequency': 4,
#    'wordform_frequency': 4},
#   {'lemma': 'мәселе',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Nom|Number=Plur|Number[psor]=Plur,Sing|Person[psor]=3',
#    'total_frequency': 4,
#    'wordform_frequency': 4},
#   {'lemma': 'бойынша',
#    'pos': 'ADP',
#    'inflection_info': None,
#    'total_frequency': 5,
#    'wordform_frequency': 5},
#   {'lemma': 'бойынша',
#    'pos': 'ADP',
#    'inflection_info': None,
#    'total_frequency': 5,
#    'wordform_frequency': 5},
#   {'lemma': 'өзгеріс',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Nom|Number=Plur',
#    'total_frequency': 4,
#    'wordform_frequency': 4},
#   {'lemma': 'өзгеріс',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Nom|Number=Plur',
#    'total_frequency': 4,
#    'wordform_frequency': 4},
#   {'lemma': 'мен',
#    'pos': 'CCONJ',
#    'inflection_info': None,
#    'total_frequency': 7,
#    'wordform_frequency': 7},
#   {'lemma': 'мен',
#    'pos': 'CCONJ',
#    'inflection_info': None,
#    'total_frequency': 7,
#    'wordform_frequency': 7},
#   {'lemma': 'мен',
#    'pos': 'CCONJ',
#    'inflection_info': None,
#    'total_frequency': 7,
#    'wordform_frequency': 7},
#   {'lemma': 'мен',
#    'pos': 'CCONJ',
#    'inflection_info': None,
#    'total_frequency': 7,
#    'wordform_frequency': 7},
#   {'lemma': 'толықтыру',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Nom|Number=Plur',
#    'total_frequency': 4,
#    'wordform_frequency': 4},
#   {'lemma': 'толықтыру',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Nom|Number=Plur',
#    'total_frequency': 4,
#    'wordform_frequency': 4},
#   {'lemma': 'енгіз',
#    'pos': 'VERB',
#    'inflection_info': 'Case=Nom|VerbForm=Ger',
#    'total_frequency': 5,
#    'wordform_frequency': 4},
#   {'lemma': 'енгіз',
#    'pos': 'VERB',
#    'inflection_info': 'Case=Nom|VerbForm=Ger',
#    'total_frequency': 5,
#    'wordform_frequency': 4},
#   {'lemma': 'енгіз',
#    'pos': 'VERB',
#    'inflection_info': 'Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin|Voice=Pass',
#    'total_frequency': 5,
#    'wordform_frequency': 1},
#   {'lemma': 'турал',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#    'total_frequency': 4,
#    'wordform_frequency': 4},
#   {'lemma': 'турал',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#    'total_frequency': 4,
#    'wordform_frequency': 4},
#   {'lemma': 'заң',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#    'total_frequency': 2,
#    'wordform_frequency': 1},
#   {'lemma': '.',
#    'pos': 'PUNCT',
#    'inflection_info': None,
#    'total_frequency': 8,
#    'wordform_frequency': 8},
#   {'lemma': '-',
#    'pos': 'PUNCT',
#    'inflection_info': None,
#    'total_frequency': 3,
#    'wordform_frequency': 3},
#   {'lemma': 'сонымен',
#    'pos': 'PRON',
#    'inflection_info': 'Case=Ins|PronType=Dem',
#    'total_frequency': 2,
#    'wordform_frequency': 2},
#   {'lemma': 'сонымен',
#    'pos': 'PRON',
#    'inflection_info': 'Case=Ins|PronType=Dem',
#    'total_frequency': 2,
#    'wordform_frequency': 2},
#   {'lemma': 'қатар',
#    'pos': 'ADP',
#    'inflection_info': None,
#    'total_frequency': 2,
#    'wordform_frequency': 2},
#   {'lemma': 'қатар',
#    'pos': 'ADP',
#    'inflection_info': None,
#    'total_frequency': 2,
#    'wordform_frequency': 2},
#   {'lemma': '2022',
#    'pos': 'NUM',
#    'inflection_info': 'NumType=Ord',
#    'total_frequency': 2,
#    'wordform_frequency': 2},
#   {'lemma': '2022',
#    'pos': 'NUM',
#    'inflection_info': 'NumType=Ord',
#    'total_frequency': 2,
#    'wordform_frequency': 2},
#   {'lemma': 'қыркүйек',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Abl|Number[psor]=Plur,Sing|Person[psor]=3',
#    'total_frequency': 2,
#    'wordform_frequency': 2},
#   {'lemma': 'қыркүйек',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Abl|Number[psor]=Plur,Sing|Person[psor]=3',
#    'total_frequency': 2,
#    'wordform_frequency': 2},
#   {'lemma': 'баста',
#    'pos': 'VERB',
#    'inflection_info': 'Aspect=Perf|VerbForm=Conv',
#    'total_frequency': 2,
#    'wordform_frequency': 2},
#   {'lemma': 'баста',
#    'pos': 'VERB',
#    'inflection_info': 'Aspect=Perf|VerbForm=Conv',
#    'total_frequency': 2,
#    'wordform_frequency': 2},
#   {'lemma': 'сақтандыру',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Nom',
#    'total_frequency': 2,
#    'wordform_frequency': 2},
#   {'lemma': 'сақтандыру',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Nom',
#    'total_frequency': 2,
#    'wordform_frequency': 2},
#   {'lemma': 'нарық',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Acc|Number[psor]=Plur,Sing|Person[psor]=3',
#    'total_frequency': 4,
#    'wordform_frequency': 4},
#   {'lemma': 'нарық',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Acc|Number[psor]=Plur,Sing|Person[psor]=3',
#    'total_frequency': 4,
#    'wordform_frequency': 4},
#   {'lemma': 'нарық',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Acc|Number[psor]=Plur,Sing|Person[psor]=3',
#    'total_frequency': 4,
#    'wordform_frequency': 4},
#   {'lemma': 'нарық',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Acc|Number[psor]=Plur,Sing|Person[psor]=3',
#    'total_frequency': 4,
#    'wordform_frequency': 4},
#   {'lemma': 'бағалы',
#    'pos': 'ADJ',
#    'inflection_info': None,
#    'total_frequency': 2,
#    'wordform_frequency': 2},
#   {'lemma': 'бағалы',
#    'pos': 'ADJ',
#    'inflection_info': None,
#    'total_frequency': 2,
#    'wordform_frequency': 2},
#   {'lemma': 'қағаз',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Nom|Number=Plur',
#    'total_frequency': 2,
#    'wordform_frequency': 2},
#   {'lemma': 'қағаз',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Nom|Number=Plur',
#    'total_frequency': 2,
#    'wordform_frequency': 2},
#   {'lemma': 'ретте',
#    'pos': 'VERB',
#    'inflection_info': 'Case=Nom|VerbForm=Ger',
#    'total_frequency': 2,
#    'wordform_frequency': 2},
#   {'lemma': 'ретте',
#    'pos': 'VERB',
#    'inflection_info': 'Case=Nom|VerbForm=Ger',
#    'total_frequency': 2,
#    'wordform_frequency': 2},
#   {'lemma': 'дамыт',
#    'pos': 'VERB',
#    'inflection_info': 'Case=Nom|VerbForm=Ger',
#    'total_frequency': 2,
#    'wordform_frequency': 2},
#   {'lemma': 'дамыт',
#    'pos': 'VERB',
#    'inflection_info': 'Case=Nom|VerbForm=Ger',
#    'total_frequency': 2,
#    'wordform_frequency': 2},
#   {'lemma': 'ҚР',
#    'pos': 'PROPN',
#    'inflection_info': 'Case=Nom',
#    'total_frequency': 1,
#    'wordform_frequency': 1},
#   {'lemma': 'аяыс',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Loc|Number[psor]=Plur,Sing|Person[psor]=3',
#    'total_frequency': 1,
#    'wordform_frequency': 1},
#   {'lemma': 'өмірд',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Acc',
#    'total_frequency': 1,
#    'wordform_frequency': 1},
#   {'lemma': 'сақтандыр',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Gen',
#    'total_frequency': 1,
#    'wordform_frequency': 1},
#   {'lemma': 'жаңа',
#    'pos': 'ADJ',
#    'inflection_info': None,
#    'total_frequency': 1,
#    'wordform_frequency': 1},
#   {'lemma': 'әлеуметтік',
#    'pos': 'ADJ',
#    'inflection_info': None,
#    'total_frequency': 1,
#    'wordform_frequency': 1},
#   {'lemma': 'маңызды',
#    'pos': 'ADJ',
#    'inflection_info': None,
#    'total_frequency': 1,
#    'wordform_frequency': 1},
#   {'lemma': 'өнім',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#    'total_frequency': 1,
#    'wordform_frequency': 1},
#   {'lemma': 'бірлес',
#    'pos': 'VERB',
#    'inflection_info': 'Tense=Past|VerbForm=Part',
#    'total_frequency': 1,
#    'wordform_frequency': 1},
#   {'lemma': 'зейнетақ',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Nom',
#    'total_frequency': 1,
#    'wordform_frequency': 1},
#   {'lemma': 'аннуитет',
#    'pos': 'NOUN',
#    'inflection_info': 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3',
#    'total_frequency': 1,
#    'wordform_frequency': 1}]}
